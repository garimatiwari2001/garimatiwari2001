# %%
import numpy as np  
import pandas as pd

# %%
colnames = ['userId', 'productId', 'ratings', 'timestamp']
ratings_data = pd.read_csv("ratings_Electronics.csv", names= colnames)  
ratings_data.head()
# Out:
#            userId   productId  ratings   timestamp
# 0   AKM1MP6P0OYPR  0132793040      5.0  1365811200
# 1  A2CX7LUOHB2NDG  0321732944      5.0  1341100800
# 2  A2NWSAGRHCP8N5  0439886341      1.0  1367193600
# 3  A2WNBOD3WNDNKT  0439886341      3.0  1374451200
# 4  A1GI0U4ZRJA8WN  0439886341      1.0  1334707200

# %%
ratings_data.shape
# Out:
# (7824482, 4)

# %%
ratings_data.dtypes
# Out:
# userId        object
# productId     object
# ratings      float64
# timestamp      int64
# dtype: object

# %%
# cutting down the record size based on user rated more than 70 times
users = ratings_data[ratings_data.groupby('userId')['userId'].transform('size') > 70]

users.shape
# Out:
# (75352, 4)

# %%
users.head()
# Out:
#               userId   productId  ratings   timestamp
# 118    AT09WGFUM934H  0594481813      3.0  1377907200
# 177   A32HSNCNPRUMTR  0970407998      1.0  1319673600
# 178   A17HMM1M7T9PJ1  0970407998      4.0  1281744000
# 631   A3TAS1AG6FMBQW  0972683275      5.0  1353456000
# 1322  A1A5KUIIIHFF4U  1400501466      1.0  1332547200

# %%
users.describe()
# Out:
#             ratings     timestamp
# count  75352.000000  7.535200e+04
# mean       4.258308  1.317145e+09
# std        1.047671  7.871472e+07
# min        1.000000  9.440064e+08
# 25%        4.000000  1.278115e+09
# 50%        5.000000  1.340928e+09
# 75%        5.000000  1.375315e+09
# max        5.000000  1.406074e+09

# %%
#Popularity Recommender Model

# %%
users.groupby('productId')['ratings'].mean().sort_values(ascending=False).head()
# Out:
# productId
# B00LKG1MC8    5.0
# B002IPHA1W    5.0
# B002IKKFIC    5.0
# B002IKLJU0    5.0
# B002IKLJUU    5.0
# Name: ratings, dtype: float64

# %%
users.groupby('productId')['ratings'].count().sort_values(ascending=False).head()
# Out:
# productId
# B0088CJT4U    131
# B003ES5ZUU    102
# B002R5AM7C     98
# B000N99BBC     98
# B00829TIEK     95
# Name: ratings, dtype: int64

# %%
ratings_mean_count = pd.DataFrame(users.groupby('productId')['ratings'].mean())

# %%
ratings_mean_count['rating_counts'] = pd.DataFrame(users.groupby('productId')['ratings'].count())

# %%
ratings_mean_count.head()
# Out:
#             ratings  rating_counts
# productId
# 0594481813      3.0              1
# 0970407998      2.5              2
# 0972683275      5.0              1
# 1400501466      2.0              2
# 1400501776      4.0              1

# %%
from surprise import Dataset,Reader

reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(users[['userId', 'productId', 'ratings']], reader)

# %%
data.df.head()
# Out:
#               userId   productId  ratings
# 118    AT09WGFUM934H  0594481813      3.0
# 177   A32HSNCNPRUMTR  0970407998      1.0
# 178   A17HMM1M7T9PJ1  0970407998      4.0
# 631   A3TAS1AG6FMBQW  0972683275      5.0
# 1322  A1A5KUIIIHFF4U  1400501466      1.0

# %%
# Split data to train and test
from surprise.model_selection import train_test_split
trainset, testset = train_test_split(data, test_size=.30,random_state=123)

# %%
from surprise import SVD
from surprise import accuracy

# %%
svd_model = SVD(n_factors=50,biased=False)
svd_model.fit(trainset)

# %%
testset
# Out:
# [('ANRS196NKFVUU', 'B000O8I474', 5.0),
#  ('A3R4794K2RVU1S', 'B0048IW030', 3.0),
#  ('AXU3VKZE848IY', 'B001SEQN3U', 5.0),
#  ('ARXU3FESTWMJJ', 'B0011000R6', 4.0),
#  ('A2JMJVNTBL7K7E', 'B002J9HBIO', 4.0),
#  ('A1L64KDYO5BOJA', 'B0019UGCLG', 4.0),
#  ('A2IFKH3TJ10387', 'B009WE65EA', 5.0),
#  ('A2NYK9KWFMJV4Y', 'B00HVMIL1U', 4.0),
#  ('A1C5WS021EL3WO', 'B00BY3XN7E', 5.0),
#  ('A2FRKEXDXDN1KI', 'B003VS9UP4', 4.0),
#  ('A1BVE2ZIBKJ7YI', 'B003HGHR82', 5.0),
#  ('A3977M5S0GIG5H', 'B003ZUIHY8', 5.0),
#  ('A7QMQBGJ2TCQG', 'B000ZPJEDE', 2.0),
#  ('A27ADCSD15F3GL', 'B00E20SSWQ', 2.0),
#  ('A2AF0NOCM71J0B', 'B008DBI6Y0', 4.0),
#  ('AS269J1OGZT1V', 'B006OSQALU', 3.0),
#  ('AROQO2VDODT7', 'B003GBRXKU', 4.0),
#  ('A30XZK10EZN9V4', 'B000G7PLCY', 5.0),
#  ('ACJT8MUC0LRF0', 'B00DK2JQOQ', 5.0),
#  ('A25HBO5V8S8SEA', 'B00023440W', 5.0),
#  ('A1CSRR7FCKBL9M', 'B003IZFCFW', 4.0),
#  ('A14JBDSWKPKTZA', 'B00006G2OJ', 5.0),
#  ('AAA0TUKS5VBSA', 'B004CLYEFK', 4.0),
#  ('ADLVFFE4VBT8', 'B0032ZZP82', 5.0),
#  ('A39137LW12KK7B', 'B000VZCEUI', 4.0),
#  ('AFICF7DKHTQ87', 'B001ENI3C4', 5.0),
#  ('A32T2H8150OJLU', 'B00BUHXQWQ', 5.0),
#  ('A1KKE6VX8VPWZK', 'B001U5YZ4G', 5.0),
#  ('A1RPTVW5VEOSI', 'B005OFK8EE', 1.0),
#  ('A2FRKEXDXDN1KI', 'B0016Q6BXC', 5.0),
#  ('A203OCQQ12MAVT', 'B000CBSGYE', 5.0),
#  ('AOEDWQLH2WKKW', 'B000H7GFWS', 2.0),
#  ('AHQRU3MRORIWQ', 'B004WIUDGM', 4.0),
#  ('A2OKRGHIYTBQ6P', 'B000HKGK8Y', 3.0),
#  ('A3EXWV8FNSSFL6', 'B0041L3JS4', 3.0),
#  ('A2V5M5EJPOD2IU', 'B00452V66G', 5.0),
#  ('A2NYK9KWFMJV4Y', 'B00IKCQ0EK', 5.0),
#  ('A2ARDVMUGDFED6', 'B002J9HBIO', 5.0),
#  ('A203OCQQ12MAVT', 'B001J8BAYW', 5.0),
#  ('A2NP9CGUSFP22E', 'B0052SCU8U', 5.0),
#  ('A37CEYB95LK6R6', 'B003TLSXMO', 5.0),
#  ('A1ILWPH1GHUXE2', 'B004431UBM', 3.0),
#  ('A1SB9BNNGKNX2Z', 'B001LK8P14', 5.0),
#  ('A38C12950IM24P', 'B00HRLSQYM', 5.0),
#  ('A1RJKTYC03L0JY', 'B004VCMIH6', 5.0),
#  ('A3DOPYDOS49I3T', 'B003MTTJOY', 5.0),
#  ('AN81JUYW2SL24', 'B00D8X0ICQ', 4.0),
#  ('A1V4VVBQBFXRHC', 'B001BM5XB2', 5.0),
#  ('A3TCMJ6GKZJFBQ', 'B000EWHH7I', 4.0),
#  ('A1IBKN1GXYJ3K4', 'B004TPJKEY', 5.0),
#  ('A250AXLRBVYKB4', 'B000Q7IA5E', 4.0),
#  ('ADLVFFE4VBT8', 'B008AGP5H4', 5.0),
#  ('A3CG93783LP0FO', 'B00ENZRP38', 4.0),
#  ('A11D1KHM7DVOQK', 'B00008ZPNR', 4.0),
#  ('A20951I210L0IB', 'B00727FE5U', 3.0),
#  ('AIJQU979J6UFY', 'B003P9W9T8', 3.0),
#  ('A2KHG3JOFXQ4CE', 'B007H3L24Q', 3.0),
#  ('A2XRMQA6PJ5ZJ8', 'B006TT91TW', 5.0),
#  ('A35W3JQYP0M655', 'B0001AGFX0', 4.0),
#  ('A3QJU4FEN8PQSZ', 'B00JAZGU3C', 4.0),
#  ('AX7317G153T8W', 'B001BN6G8A', 4.0),
#  ('ACYZXQ2JKPZKT', 'B000VUKQPI', 5.0),
#  ('A17O9AHKHK66AI', 'B00DZTVST0', 5.0),
#  ('A3REK3OFONWB1Q', 'B003Y2TD36', 5.0),
#  ('A1SB9BNNGKNX2Z', 'B0025VKUQ6', 4.0),
#  ('A3H4S6YO9VNGDZ', 'B004VFJTE8', 4.0),
#  ('A25C2M3QF9G7OQ', 'B004CLYEDC', 4.0),
#  ('A1JWSDDIH5Z7DV', 'B0002F7I9O', 5.0),
#  ('A2L9OPJAAEK08Q', 'B001AOK96A', 5.0),
#  ('A38QEATH3NODFM', 'B000EHCUIE', 4.0),
#  ('A20DZX38KRBIT8', 'B000VXVI3O', 3.0),
#  ('A2JP9E1H0SF392', 'B007MH75J8', 5.0),
#  ('ALRCAGJOJ9583', 'B00DAO7KF6', 5.0),
#  ('A38RMU1Y5TDP9', 'B00HFW1E6K', 5.0),
#  ('A1WXG10FJ353K0', 'B003O9HBBU', 5.0),
#  ('A2JWF9IG8PJAOA', 'B00DBV28TG', 5.0),
#  ('A2PMR2PIGWKCQ9', 'B0054U6CEE', 5.0),
#  ('A1ILWPH1GHUXE2', 'B002OL2I30', 4.0),
#  ('A2NOW4U7W3F7RI', 'B0006ON0QQ', 5.0),
#  ('A3TRY87JJCA5Y8', 'B007Q45EF4', 4.0),
#  ('A6FIAB28IS79', 'B000NDO744', 3.0),
#  ('A7QMQBGJ2TCQG', 'B0000ALKAN', 5.0),
#  ('ADKZOXAOV8EXD', 'B0096W1OCG', 5.0),
#  ('A250AXLRBVYKB4', 'B001J8AM7I', 2.0),
#  ('A3D6OI36USYOU1', 'B004CJ95JW', 4.0),
#  ('A10NMELR4KX0J6', 'B000Z80ICM', 2.0),
#  ('AEL6CQNQXONBX', 'B0009RGLSE', 5.0),
#  ('A1VFX417XDNWIU', 'B003WE9WV4', 4.0),
#  ('A5JLAU2ARJ0BO', 'B008V63D3Q', 5.0),
#  ('A15T9G38F589KM', 'B009NE5YYQ', 3.0),
#  ('A54SG05AV6S4H', 'B0059KEFMK', 5.0),
#  ('A1E55W6ES0FY17', 'B0006ADJYS', 1.0),
#  ('A1QOK9LU90ACF7', 'B000EDKO04', 4.0),
#  ('A2F7CSE6KT7NI4', 'B0037BQJPE', 1.0),
#  ('A1CSRR7FCKBL9M', 'B000UY3NR8', 3.0),
#  ('A2NB2E5DXE319Z', 'B005C6CVAE', 5.0),
#  ('A22S7D0LP8GRDH', 'B004CLYEE6', 4.0),
#  ('A2RU4U1JZ3DMP5', 'B0031AQ302', 4.0),
#  ('A25WJCAP606YMP', 'B004GF1PC2', 5.0),
#  ('AAR7CEPXYJA0T', 'B003D3NDCS', 5.0),
#  ('A2V5M5EJPOD2IU', 'B006B7R9PU', 5.0),
#  ('A19UTUEBWKIZFT', 'B002SZEOLG', 5.0),
#  ('A3DGJMO6VPG6FJ', 'B009X2OS72', 4.0),
#  ('A1VLVWTLV3LVHR', 'B000NO9FVI', 4.0),
#  ('A1CSRR7FCKBL9M', 'B004M8ST36', 5.0),
#  ('A1143YEAZYMYHJ', 'B00004ZEPB', 5.0),
#  ('A3EFSLEMHNPP6A', 'B008R91OZ6', 5.0),
#  ('A2503LT8PZIHAD', 'B001R4BTLC', 5.0),
#  ('A2EW01G2LNJN06', 'B004EYSNTI', 5.0),
#  ('AKT8TGIT6VVZ5', 'B006HUMYCO', 5.0),
#  ('A3LWC833HQIG7J', 'B00114PN24', 1.0),
#  ('A10PEXB6XAQ5XF', 'B003TP03TQ', 2.0),
#  ('A1U4GOVZWL8ZTL', 'B007BY3PBE', 5.0),
#  ('AEWYUPCNDV7HY', 'B0015HYPOO', 4.0),
#  ('ADZF3QDGSZE7K', 'B00A2BVBTG', 5.0),
#  ('AGVWTYW0ULXHT', 'B000VFYLR2', 4.0),
#  ('A2PREU4LOFQRB1', 'B005CT56F8', 5.0),
#  ('A3MQ15651KGVLJ', 'B00BCPGNVC', 5.0),
#  ('A11I1I9QLMAM1A', 'B003L77Y5I', 3.0),
#  ('A3QNQQKJTL76H0', 'B003RRYAXQ', 5.0),
#  ('A2I6GN7OHB9JKF', 'B00009YFTI', 5.0),
#  ('A2DG63DN704LOI', 'B00ATM1M92', 4.0),
#  ('A316XO4RWX21YN', 'B002QAUN2M', 5.0),
#  ('A2VALCFTOWFYXZ', 'B003L14YFC', 5.0),
#  ('A18HE80910BTZI', 'B000NTM9SY', 4.0),
#  ('A3NHUQ33CFH3VM', 'B00GLJGJTA', 5.0),
#  ('AGXMC3ITWZASE', 'B0002RPPF6', 1.0),
#  ('A19HKRB4LU5YR', 'B00CL8F98W', 4.0),
#  ('A2KYRPDKVBI2R4', 'B003YTSXYO', 5.0),
#  ('A1CMD08Z49PGKQ', 'B000T9B46G', 5.0),
#  ('A38RMU1Y5TDP9', 'B00FLZ2F5W', 4.0),
#  ('A2TKWMX4563NR6', 'B000BSJFJS', 1.0),
#  ('A259MPG6SOL02P', 'B00005T3Y4', 4.0),
#  ('A2QI2NTDTMK2FV', 'B001NEJO2W', 4.0),
#  ('A1TDR7Y90SVCHL', 'B0083R9QQG', 4.0),
#  ('A30X750M8V1XXW', 'B004K4THQK', 5.0),
#  ('A17BUUBOU0598B', 'B005O88CY4', 4.0),
#  ('A24HWYHR28JJ7A', 'B003G2YZ4G', 5.0),
#  ('A3Q4TYJVAM4IRM', 'B003CFATT2', 5.0),
#  ('A2TVH2OBNXYXHV', 'B000PDLZ1A', 4.0),
#  ('A1H98YV5K5BUX0', 'B004SIMNF0', 5.0),
#  ('A7QMQBGJ2TCQG', 'B000P5UKZA', 5.0),
#  ('A2AF0NOCM71J0B', 'B008LTBHYU', 4.0),
#  ('A2AF0NOCM71J0B', 'B001CIOSZC', 3.0),
#  ('AYLLSFYS3UP1H', 'B00GD1KEEC', 4.0),
#  ('A2TKWMX4563NR6', 'B001NPEBGU', 5.0),
#  ('ABQWMANK4AR63', 'B005O7QC10', 2.0),
#  ('A54S9CIUV5VNB', 'B004GF8TIK', 5.0),
#  ('AGX2K0FMS0IVL', 'B007WTAJTO', 5.0),
#  ('A100UD67AHFODS', 'B00998P1JY', 4.0),
#  ('A2V1J3JT5OOZFO', 'B00945RAQY', 3.0),
#  ('ATZJNEXX7LWD3', 'B00DR8L7M2', 4.0),
#  ('A3RGJ1FXOB1ZLL', 'B00B2X0SME', 5.0),
#  ('A7EJERNB7IK3Z', 'B001EO13RA', 5.0),
#  ('A1VHCO8RQFIGQJ', 'B009GGC4B2', 5.0),
#  ('A3MFORLOKIOEQY', 'B003UDCPEI', 5.0),
#  ('AZAC8O310IK4E', 'B000HDJT4S', 4.0),
#  ('A2NYK9KWFMJV4Y', 'B00007KDVI', 3.0),
#  ('A35HNL2VEDK9Z1', 'B007JCNOZA', 5.0),
#  ('A1CMD08Z49PGKQ', 'B008MPVQTY', 3.0),
#  ('A33775AIB1A664', 'B004DVEWH4', 4.0),
#  ('A3DGJMO6VPG6FJ', 'B0019X20R8', 2.0),
#  ('A3MQ15651KGVLJ', 'B005QCDY50', 2.0),
#  ('A1PI8VBCXXSGC7', 'B00FJISZ28', 4.0),
#  ('A18FLOC8YQY0P8', 'B00409EJ40', 5.0),
#  ('A1U4GOVZWL8ZTL', 'B0024NKHAY', 5.0),
#  ('A2WXURU33RBGQS', 'B0002EBF6C', 4.0),
#  ('A3R19YKNL641X3', 'B0021L9HKK', 2.0),
#  ('A2ROZACRW31PC2', 'B0018DJF4K', 4.0),
#  ('A2W9GX82SLKROQ', 'B003QJX1K8', 4.0),
#  ('A1E1LEVQ9VQNK', 'B00KH8PU6E', 5.0),
#  ('AEZJTA4KDIWY8', 'B003VWY0VY', 4.0),
#  ('A1MZL91Z44RN06', 'B0006PKY5A', 5.0),
#  ('AGVWTYW0ULXHT', 'B00CRXZSYQ', 4.0),
#  ('A29KJ32G75L7G9', 'B00AKXOVG6', 3.0),
#  ('A2R6RA8FRBS608', 'B003LVZO8I', 5.0),
#  ('A1ODOGXEYECQQ8', 'B00IORDBPC', 4.0),
#  ('A1H6SBO7R007I8', 'B004H8FNC6', 4.0),
#  ('A1H98YV5K5BUX0', 'B004YHWI7S', 2.0),
#  ('AWNJAY0M5UI70', 'B0079EVQ2Q', 5.0),
#  ('A4IL0CLL27Q33', 'B0055E0JMA', 5.0),
#  ('A2VH0UT5EQFB6P', 'B007H3L24Q', 3.0),
#  ('A2V1J3JT5OOZFO', 'B003M2YP6S', 5.0),
#  ('A2D1LPEUCTNT8X', 'B00AASPQLU', 5.0),
#  ('AAQ9NJ480N9W5', 'B00004ZCAT', 5.0),
#  ('A1J75JJ0Q2OEJN', 'B009VV56TY', 5.0),
#  ('A1CMD08Z49PGKQ', 'B007B31IAK', 5.0),
#  ('A1PL7QILVQV3IF', 'B001Q3M9PY', 3.0),
#  ('A2W2ODLRQ2L8LE', 'B0034CTWLE', 4.0),
#  ('A1T1YSCDW0PD25', 'B001S2RCWI', 2.0),
#  ('A2JWF9IG8PJAOA', 'B007XCVFV6', 5.0),
#  ('AGXV8E7XK9J6H', 'B0038KRDMM', 4.0),
#  ('A3D6OI36USYOU1', 'B00A02N3VQ', 2.0),
#  ('A204K1OFE8OB9Y', 'B009LNUJBC', 3.0),
#  ('A1TQZUSOU22E9M', 'B0009GZAGO', 5.0),
#  ('ADOR3TR7GDF68', 'B00915OTZC', 4.0),
#  ('A3A15L96IYUO6V', 'B00000JBTM', 5.0),
#  ('A2QRXQPHDMFCQV', 'B000H6QH22', 4.0),
#  ('A2X78O6G89CB30', 'B004TJ6JH6', 4.0),
#  ('A3Q4TYJVAM4IRM', 'B000W67G72', 5.0),
#  ('A22I55P15NSAOX', 'B0016HZSJO', 4.0),
#  ('A2UKE7GIVC7XFW', 'B00119T6NQ', 5.0),
#  ('A30XZK10EZN9V4', 'B007G3DQI2', 4.0),
#  ('A1EXGL6L0QQ0M5', 'B0009I4VE4', 5.0),
#  ('A370XYLIZCSK1Y', 'B000WN00FK', 4.0),
#  ('A1E1LEVQ9VQNK', 'B00D741DRK', 5.0),
#  ('A18YMFFJW974QS', 'B003QP41EC', 5.0),
#  ('A1VVRA3P6G1TWH', 'B00004ZCJE', 4.0),
#  ('A2NVQZ4Y7Y0J1R', 'B003CYKYU2', 3.0),
#  ('A1E1LEVQ9VQNK', 'B003ES5ZR8', 5.0),
#  ('A2EN82VBJT44QP', 'B003IZ9XTI', 5.0),
#  ('ADLVFFE4VBT8', 'B009QV72VY', 4.0),
#  ('A1UQBFCERIP7VJ', 'B00IP8IBYG', 5.0),
#  ('A2AEZQ3DGBBLPR', 'B00005YVPI', 5.0),
#  ('A3QMJMTLJC34QC', 'B0000304ZO', 4.0),
#  ('A3CG93783LP0FO', 'B003FG7IDI', 2.0),
#  ('A5JLAU2ARJ0BO', 'B0002IG34W', 4.0),
#  ('AYMD77ITD15PT', 'B000A1AQOO', 5.0),
#  ('A3A4ZAIBQWKOZS', 'B00FF6J532', 5.0),
#  ('A28BX3MM90A6FI', 'B005LZR0DO', 5.0),
#  ('A1T1YSCDW0PD25', 'B00JOS04PK', 5.0),
#  ('A3CW0ZLUO5X2B1', 'B003F8UWUM', 5.0),
#  ('A2NOW4U7W3F7RI', 'B0085MQLGC', 5.0),
#  ('A34UVV757IKPVB', 'B0002VFWSW', 5.0),
#  ('A32O5FZH994CNY', 'B0021YZ6AM', 4.0),
#  ('A2T689YVOAYGGD', 'B002QEBMAK', 5.0),
#  ('A18FLOC8YQY0P8', 'B00BPZCYK8', 5.0),
#  ('AGGAQLXPVGM5D', 'B000ZIEOPY', 4.0),
#  ('AYLLSFYS3UP1H', 'B007FH1KAU', 4.0),
#  ('AZ515FFZ7I2P7', 'B0008032NY', 5.0),
#  ('A2ARDVMUGDFED6', 'B001CK0BHO', 5.0),
#  ('A3V2EZ6MA32FF6', 'B002HWRJY4', 5.0),
#  ('A3LZA698SQPCXE', 'B00AR95FP4', 4.0),
#  ('ABVYGB2TKBO8F', 'B000FNBI5S', 5.0),
#  ('ADKZOXAOV8EXD', 'B000SY1PQ6', 1.0),
#  ('A23NSKTMSPPBTR', 'B00IQ0SE22', 4.0),
#  ('A28BX3MM90A6FI', 'B003VZO5S4', 4.0),
#  ('A203OCQQ12MAVT', 'B001S4OTS6', 5.0),
#  ('A5JLAU2ARJ0BO', 'B00061HVKU', 5.0),
#  ('A2WJ5XSE4I9F55', 'B000CSPK5K', 5.0),
#  ('A26SO3TOT2TLJE', 'B00829TIEK', 5.0),
#  ('A225G2TFM76GYX', 'B00CRJWW2G', 5.0),
#  ('A105TOJ6LTVMBG', 'B000I4RFO2', 4.0),
#  ('A3NEAETOSXDBOM', 'B00HZ9GODQ', 2.0),
#  ('A2X78O6G89CB30', 'B00358PJSM', 4.0),
#  ('A3F9CMU8KNAY1M', 'B00IO69GVQ', 4.0),
#  ('A18YMFFJW974QS', 'B000E0I9K4', 4.0),
#  ('A1URXSRV6WDHVY', 'B005A0B3MO', 3.0),
#  ('A1GQRGB8FGSLIZ', 'B003WVFAO0', 2.0),
#  ('AP53MVRC8ZEW2', 'B00J8DUK4Q', 5.0),
#  ('A2XA8CW5DF4MNZ', 'B00EZJQVG4', 3.0),
#  ('A1U5IJHJK84S54', 'B00009R97U', 5.0),
#  ('A2SH6A32BE6NEV', 'B002UKOUTK', 4.0),
#  ('AGR1V15L6FLMA', 'B004S4R5CK', 5.0),
#  ('AOWF9T81XMX2S', 'B0002GRUV4', 4.0),
#  ('A2UTZ4O5E2W4DK', 'B000F28DP2', 3.0),
#  ('A3PDWA32BAMB2Y', 'B003CKC8W8', 4.0),
#  ('AWPODHOB4GFWL', 'B000OFW65I', 5.0),
#  ('A6FIAB28IS79', 'B000BVV2IC', 4.0),
#  ('A197T2N6RU7K56', 'B000H02B6O', 5.0),
#  ('A1ZU55TM45Y2R8', 'B008X9Z8NE', 5.0),
#  ('AVPNQUVZWMDSX', 'B002AVXDWE', 5.0),
#  ('A203OCQQ12MAVT', 'B000MNBWF2', 5.0),
#  ('A28N2AWOVO2PB', 'B007LLYAB6', 5.0),
#  ('A3D0UM4ZD2CMAW', 'B008D1JKF4', 5.0),
#  ('A20VG5W98SX99L', 'B0064XAIZY', 4.0),
#  ('A2D1LPEUCTNT8X', 'B000KCSS34', 1.0),
#  ('A2UKE7GIVC7XFW', 'B009A6CZYY', 3.0),
#  ('A1U5IJHJK84S54', 'B005HQ5O8K', 5.0),
#  ('A231WM2Z2JL0U3', 'B000023VUL', 5.0),
#  ('A38QEATH3NODFM', 'B000050GSF', 5.0),
#  ('ACHTDPEQYSEQL', 'B0013FW8XS', 4.0),
#  ('A1R377IPZOKLMM', 'B003XDU2Y0', 5.0),
#  ('A1ZTR0FR5AW9B4', 'B005HN5CUS', 4.0),
#  ('A19HT7YC1UW3D6', 'B003LRY9Q0', 5.0),
#  ('A1VHCO8RQFIGQJ', 'B003SQEAY0', 5.0),
#  ('A3TAS1AG6FMBQW', 'B00934CQ56', 5.0),
#  ('AEJAGHLC675A7', 'B000UXZQ42', 4.0),
#  ('A680RUE1FDO8B', 'B0007LDI3I', 4.0),
#  ('ALDAF4VVLFRHP', 'B001TSMJDS', 4.0),
#  ('A203OCQQ12MAVT', 'B0002D6QJO', 5.0),
#  ('AKT8TGIT6VVZ5', 'B00006I5E4', 4.0),
#  ('AX05DBU8IRUWY', 'B0000VYJRY', 5.0),
#  ('A5JLAU2ARJ0BO', 'B0007YN3F8', 3.0),
#  ('A23ZNGL704AW7O', 'B00CF5OHZ2', 5.0),
#  ('A3FOSLM5G1BO63', 'B009WZRCO6', 4.0),
#  ('A2TKWMX4563NR6', 'B0007LQKME', 3.0),
#  ('A3NHUQ33CFH3VM', 'B004BQKQ8A', 5.0),
#  ('AHF4I1FSIHABC', 'B00006I53W', 5.0),
#  ('A1R377IPZOKLMM', 'B0010TEOLQ', 5.0),
#  ('A35W3JQYP0M655', 'B004RO3QLU', 4.0),
#  ('AR74YY08IP2WE', 'B005EOWBKE', 4.0),
#  ('A5JLAU2ARJ0BO', 'B0006O4VMI', 4.0),
#  ('A2WW57XX2UVLM6', 'B000VSWHIE', 5.0),
#  ('A3EXWV8FNSSFL6', 'B00G2TK76A', 5.0),
#  ('A2KHG3JOFXQ4CE', 'B0068ALVAO', 3.0),
#  ('A2AY4YUOX2N1BQ', 'B00009R7SE', 5.0),
#  ('AR3EVUQF0AC7R', 'B00020S7XK', 4.0),
#  ('A24HWYHR28JJ7A', 'B0099SMFVQ', 5.0),
#  ('A1K4G5YJDJQI6Q', 'B0018Q09C4', 1.0),
#  ('A149RNR5RH19YY', 'B001S2PK72', 5.0),
#  ('A3QNX5KWHDV0GD', 'B0032H2EEI', 5.0),
#  ('A2NOW4U7W3F7RI', 'B007P4VOWC', 4.0),
#  ('A3OXHLG6DIBRW8', 'B00HJ1NQLS', 5.0),
#  ('A1E1LEVQ9VQNK', 'B003LVZO88', 5.0),
#  ('A3IOQ7NVVLAUEE', 'B0002KR7FY', 5.0),
#  ('A2AX2UGB167J31', 'B0002GOH42', 5.0),
#  ('A5JLAU2ARJ0BO', 'B003TOWYZ8', 4.0),
#  ('ACY9QYNDFLVBI', 'B003LZ5SM6', 5.0),
#  ('A1RPTVW5VEOSI', 'B00004TDPP', 3.0),
#  ('A2F7CSE6KT7NI4', 'B004SUO3SS', 5.0),
#  ('A33YZNZIRA3H97', 'B000FFIYOO', 4.0),
#  ('A2B7BUH8834Y6M', 'B0009EXWJS', 4.0),
#  ('A36K2N527TXXJN', 'B0035FZJHQ', 5.0),
#  ('A38RMU1Y5TDP9', 'B009M3UT16', 5.0),
#  ('A3EZFFPVS34AMO', 'B000138VFW', 5.0),
#  ('A3CG93783LP0FO', 'B001HL0G5K', 5.0),
#  ('A1O229NVVDJUX2', 'B003VAHYNC', 5.0),
#  ('A1435P5AMCPB3X', 'B000FONSEQ', 5.0),
#  ('A38NHXL5257E3B', 'B008IDC3H4', 3.0),
#  ('A1O229NVVDJUX2', 'B0036VO6IC', 4.0),
#  ('A26BDXG9KVH7SU', 'B005TDWSJ4', 3.0),
#  ('A370XYLIZCSK1Y', 'B0087X7262', 5.0),
#  ('A2L4ZGN7GZJ95T', 'B006MPUTBC', 5.0),
#  ('AWPODHOB4GFWL', 'B00EVWX8R0', 5.0),
#  ('A5JLAU2ARJ0BO', 'B0000659UB', 5.0),
#  ('ARXU3FESTWMJJ', 'B003CYKYU2', 3.0),
#  ('A100WO06OQR8BQ', 'B00030DEQE', 5.0),
#  ('AG7EF0SVBQOUX', 'B002FFG6JC', 5.0),
#  ('A1UEL5C1N6E5SE', 'B001A4HAFS', 5.0),
#  ('A2JMJVNTBL7K7E', 'B00DIOALPE', 4.0),
#  ('A1EXGL6L0QQ0M5', 'B005276QS6', 4.0),
#  ('A6FIAB28IS79', 'B000Y9PJ4O', 5.0),
#  ('A38RMU1Y5TDP9', 'B001DQKHX0', 3.0),
#  ('A27H0T39U3FZB5', 'B004YIZWYI', 3.0),
#  ('A22S7D0LP8GRDH', 'B00006B8E3', 5.0),
#  ('AC6Z7DP1Z5GHD', 'B00CBO14FI', 3.0),
#  ('A2UWPPU5GZLMQZ', 'B009T0NNRO', 4.0),
#  ('ABIVKBMSIPEDY', 'B0054YF0C0', 1.0),
#  ('A1UQBFCERIP7VJ', 'B00BWJW7UO', 5.0),
#  ('A1TQZUSOU22E9M', 'B003ES5ZUU', 5.0),
#  ('A3OXHLG6DIBRW8', 'B008R7EVE4', 5.0),
#  ('A33775AIB1A664', 'B004CLYJ14', 3.0),
#  ('A1CM4HI4S5P0WO', 'B002LITI7K', 4.0),
#  ('A1U4GOVZWL8ZTL', 'B00415ZMF8', 5.0),
#  ('A3NEAETOSXDBOM', 'B0045371FU', 4.0),
#  ('A3IOQ7NVVLAUEE', 'B00BR22W0Q', 5.0),
#  ('A3CG93783LP0FO', 'B00006BBA5', 4.0),
#  ('A19HKRB4LU5YR', 'B004CLYEH8', 3.0),
#  ('A3FPSY1M6G7XIB', 'B000V5P90K', 5.0),
#  ('A33HIV8RXRDM88', 'B003NYJEZW', 2.0),
#  ('A37IRE9GZ0CZ7I', 'B006AR2SKW', 3.0),
#  ('AYMD77ITD15PT', 'B003FSTAFK', 3.0),
#  ('ARX7Z3NI6O0F7', 'B00BVQXG1W', 4.0),
#  ('A1EXGL6L0QQ0M5', 'B00A34GP52', 5.0),
#  ('A2IFGGXG3YV3Y6', 'B00BWL33H8', 5.0),
#  ('A2JXS1JII6SAUD', 'B001P5CAV6', 5.0),
#  ('A2NSMJVQY0RV9S', 'B001KBZ3QO', 4.0),
#  ('A34CSXOGVYF94S', 'B0017PG8KS', 5.0),
#  ('A1V4VVBQBFXRHC', 'B003SGCO3E', 5.0),
#  ('A2LXX47A0KMJVX', 'B009JP461G', 4.0),
#  ('A1A5KUIIIHFF4U', 'B0026SKZO0', 1.0),
#  ('AY6A8KPYCE6B0', 'B00370BDAQ', 5.0),
#  ('A30X750M8V1XXW', 'B0028AD7BE', 4.0),
#  ('A2D1ZQEFS1NBH2', 'B000VXQZA0', 1.0),
#  ('AT28RL25Q2OLK', 'B0040HEF2I', 3.0),
#  ('A34VRVI4CSI5RQ', 'B00DT04I9W', 5.0),
#  ('AMUP8DYE7EAN2', 'B00904JILO', 3.0),
#  ('A4D5B7Q8A7PA6', 'B002WE4HE2', 5.0),
#  ('A1JUBRIZMO0RJV', 'B004YLCO64', 5.0),
#  ('A2AY4YUOX2N1BQ', 'B003AJXUTQ', 5.0),
#  ('A36K2N527TXXJN', 'B0047ZH0B6', 5.0),
#  ('A2OKRGHIYTBQ6P', 'B003WVML9M', 5.0),
#  ('A3MUSWDCTZINQZ', 'B009O7XO8U', 4.0),
#  ('AWPODHOB4GFWL', 'B0058GK55Q', 4.0),
#  ('A36K2N527TXXJN', 'B00H7HDQIC', 5.0),
#  ('A3R4794K2RVU1S', 'B005HMKKH4', 5.0),
#  ('A3JU990UTN5RQP', 'B002AYIWT0', 2.0),
#  ('AC6Z7DP1Z5GHD', 'B003D5MZUW', 4.0),
#  ('AG7EF0SVBQOUX', 'B003Y60DZO', 5.0),
#  ('A2LXX47A0KMJVX', 'B001U0O7T4', 3.0),
#  ('A2T689YVOAYGGD', 'B003ARSZ0C', 3.0),
#  ('AVSMRPI23DQI2', 'B007X6XJ98', 5.0),
#  ('A149RNR5RH19YY', 'B000BO0SGG', 4.0),
#  ('A3NHUQ33CFH3VM', 'B004Q0PT3I', 4.0),
#  ('A1EKSETIBS9ETQ', 'B000I7YOT8', 4.0),
#  ('A2SYAQXJGRY3XE', 'B007QOX5A0', 5.0),
#  ('A2XIOXRRYX0KZY', 'B00CM0XHNS', 5.0),
#  ('A3CW0ZLUO5X2B1', 'B00009MVKV', 1.0),
#  ('A2TKWMX4563NR6', 'B00BKXWESW', 5.0),
#  ('ASCBJEPXTOU0V', 'B00CKNOVLO', 1.0),
#  ('A3T7V207KRDE2O', 'B004N627KS', 5.0),
#  ('A1V3TRGWOMA8LC', 'B005GOINEK', 5.0),
#  ('AT6CZDCP4TRGA', 'B0001LGXO0', 1.0),
#  ('A3F9CBHV4OHFBS', 'B005EOWBKE', 5.0),
#  ('A7UPJYPAH73NC', 'B005TDWY4I', 5.0),
#  ('A2BMZRO0H7TFCS', 'B0046A8MQO', 4.0),
#  ('A1U4GOVZWL8ZTL', 'B003G4G6VY', 5.0),
#  ('A34CSXOGVYF94S', 'B00EL8NIJC', 5.0),
#  ('A31N0XY2UTB25C', 'B0035PS55O', 5.0),
#  ('ARBKYIVNYWK3C', 'B00IWQREOE', 5.0),
#  ('A23ZNGL704AW7O', 'B004G8QO8E', 5.0),
#  ('A8X8D4BUY5DFU', 'B009XHO7LE', 5.0),
#  ('A2NSXY5L42ZUGO', 'B001E1Y5O6', 4.0),
#  ('APBB297H3ZA5E', 'B003ZUIHY8', 5.0),
#  ('A2OWR5G2OAQF7C', 'B009AR2MD2', 5.0),
#  ('AM3XNQU9TZBD8', 'B005FNH9RE', 5.0),
#  ('A25FL6VLD7S23S', 'B003CK10DG', 5.0),
#  ('A353U0L2HAMSHV', 'B001CF2TYC', 4.0),
#  ('A1GWG5CWLKJ7ET', 'B0081H8TRA', 5.0),
#  ('A680RUE1FDO8B', 'B000NPCI9I', 5.0),
#  ('A2W9GX82SLKROQ', 'B0019M7WCW', 4.0),
#  ('A2WJ5XSE4I9F55', 'B008CHJEEQ', 3.0),
#  ('A3CW0ZLUO5X2B1', 'B008NI6D5C', 4.0),
#  ('A1LD5SE8IZ1H70', 'B005CLMJLU', 2.0),
#  ('A32T2H8150OJLU', 'B004CZ9U96', 5.0),
#  ('A2XA8CW5DF4MNZ', 'B0025VKUQ6', 4.0),
#  ('A32O5FZH994CNY', 'B000DLBJ0G', 5.0),
#  ('ALUNVOQRXOZIA', 'B00065AO0K', 5.0),
#  ('AT28RL25Q2OLK', 'B005KSZ430', 5.0),
#  ('A1IU7S4HCK1XK0', 'B0002ZAEYA', 5.0),
#  ('ATFBVUXDIRXT6', 'B00IEOEDSY', 5.0),
#  ('A2WPL6Y08K6ZQH', 'B00BGGDVOO', 4.0),
#  ('AV8MDYLHHTUOY', 'B0078ZZ5NM', 4.0),
#  ('A2WPL6Y08K6ZQH', 'B00FSKQNEY', 4.0),
#  ('A21INUA35HX4XQ', 'B00007KDX5', 5.0),
#  ('A8X8D4BUY5DFU', 'B001WFUPWU', 5.0),
#  ('A23GFTVIETX7DS', 'B004K1EZDS', 5.0),
#  ('A3OA4DV4L81N1D', 'B007Q5GUZQ', 4.0),
#  ('A3W4D8XOGLWUN5', 'B002GEA4U4', 2.0),
#  ('A4UGMKUSX9XHI', 'B0002Y5WZC', 5.0),
#  ('A11I1I9QLMAM1A', 'B00E3RH5W2', 5.0),
#  ('A2NOW4U7W3F7RI', 'B00GLL40SA', 5.0),
#  ('A1SB9BNNGKNX2Z', 'B0085YTDM4', 2.0),
#  ('AYLLSFYS3UP1H', 'B001BWLA8W', 4.0),
#  ('A2J8T58Z4X15IO', 'B005HY4UPK', 5.0),
#  ('A1U4GOVZWL8ZTL', 'B005JTTRB0', 4.0),
#  ('A2QDOJFFLFGF18', 'B00DQZQPNM', 5.0),
#  ('A11YOTONCPRQ9S', 'B005FYNSPK', 5.0),
#  ('AAQ9NJ480N9W5', 'B003TLAMV4', 5.0),
#  ('A1GQRGB8FGSLIZ', 'B004QMA3U0', 3.0),
#  ('A1EXGL6L0QQ0M5', 'B00BCGV0KA', 5.0),
#  ('A2NSXY5L42ZUGO', 'B003EWGD1Q', 5.0),
#  ('A11T807LX2EF00', 'B0012GQZZU', 5.0),
#  ('A20DDH4NT6Q1E8', 'B003EYVEVS', 5.0),
#  ('A1QVFHPY8418HC', 'B005OEIY8W', 3.0),
#  ('AVPNQUVZWMDSX', 'B004N6259G', 2.0),
#  ('A10PEXB6XAQ5XF', 'B007WVA2PI', 3.0),
#  ('A1QNYLBG73QRNF', 'B000NI569E', 5.0),
#  ('A27T4RQ3XA661C', 'B00004ZD37', 4.0),
#  ('A3LGT6UZL99IW1', 'B002SEUX7Q', 3.0),
#  ('AVPNQUVZWMDSX', 'B00FSKQNEY', 4.0),
#  ('A22MANL4US4RMY', 'B000OTIUQS', 5.0),
#  ('ALQ4USPEQ9L5N', 'B00DDQ4AZY', 4.0),
#  ('A3S5EXYZDEBF3K', 'B002LVUQYQ', 4.0),
#  ('A240FRPD4MEXND', 'B005FNYADA', 5.0),
#  ('ACY9QYNDFLVBI', 'B003YH2GH6', 5.0),
#  ('A1E1LEVQ9VQNK', 'B003ZYF3M8', 5.0),
#  ('A26KXNN6H1IL0I', 'B00004ZCC2', 4.0),
#  ('A2WLNSZ9U0T1S3', 'B000AM8SK2', 5.0),
#  ('A2UWPPU5GZLMQZ', 'B009DJ1OFY', 4.0),
#  ('A11I1I9QLMAM1A', 'B00HGE3C5I', 3.0),
#  ('A2F7CSE6KT7NI4', 'B002G1YNQS', 5.0),
#  ('ADOR3TR7GDF68', 'B000233WJ6', 5.0),
#  ('A1SHHQSPOWR00F', 'B0009HN57Y', 3.0),
#  ('A87N6UTYA6NOB', 'B00025O87Y', 4.0),
#  ('A10Y058K7B96C6', 'B004VM1T5S', 4.0),
#  ('A27ADCSD15F3GL', 'B004BDORCO', 5.0),
#  ('A1RPTVW5VEOSI', 'B000EI3TZ6', 5.0),
#  ('APBB297H3ZA5E', 'B000MULXPO', 5.0),
#  ('A2BLFCOPSMBOZ9', 'B001TIG36C', 5.0),
#  ('AT09WGFUM934H', 'B002DUKPN2', 5.0),
#  ('A2T3S3VTW65VO5', 'B002U1ZBG0', 4.0),
#  ('A1ODOGXEYECQQ8', 'B005HMKKH4', 5.0),
#  ('A1ZU55TM45Y2R8', 'B006WHPQCC', 4.0),
#  ('A3R19YKNL641X3', 'B00KJJW36G', 5.0),
#  ('A3U41ZL33SS92P', 'B007HZLLOK', 3.0),
#  ('AQIJ3ZEEVCIKU', 'B00584WZKG', 5.0),
#  ('A2T3S3VTW65VO5', 'B004NSUMN0', 5.0),
#  ('AV8MDYLHHTUOY', 'B00009KIYM', 2.0),
#  ('AGX2K0FMS0IVL', 'B0034XS250', 5.0),
#  ('A96JD9312DHWC', 'B00F0S0DK4', 5.0),
#  ('AV8MDYLHHTUOY', 'B00EL8NII8', 5.0),
#  ('A1OMXVXXP07F05', 'B005QCDY50', 4.0),
#  ('AN81JUYW2SL24', 'B004CLYEDC', 4.0),
#  ('AOEAD7DPLZE53', 'B006OSQALU', 4.0),
#  ('A3TRY87JJCA5Y8', 'B0042GHI8U', 5.0),
#  ('A1IU7S4HCK1XK0', 'B00DQZQPNM', 4.0),
#  ('AXYM52DNK6NDF', 'B001A1TMQQ', 5.0),
#  ('A1UQBFCERIP7VJ', 'B00DS5QZRQ', 5.0),
#  ('A2294LS59GC5K7', 'B000GU88CQ', 5.0),
#  ('ARBKYIVNYWK3C', 'B00016W66Y', 4.0),
#  ('A23ZNGL704AW7O', 'B00EOYSH94', 4.0),
#  ('A16QODENBJVUI1', 'B003AAIV94', 5.0),
#  ('A19W47CXJJP1MI', 'B005GTNZUM', 5.0),
#  ('A3MQ15651KGVLJ', 'B0083ZEK5K', 5.0),
#  ('A105TOJ6LTVMBG', 'B00000J1V5', 4.0),
#  ('A26BDXG9KVH7SU', 'B000CKVOOY', 5.0),
#  ('A3BVN2QBNPBHCR', 'B002B4P788', 5.0),
#  ('A2DG63DN704LOI', 'B000EW9Y4M', 5.0),
#  ('A2QI2NTDTMK2FV', 'B00001O2ZT', 5.0),
#  ('A2ARDVMUGDFED6', 'B0049HFC0S', 5.0),
#  ('A1R377IPZOKLMM', 'B000I4UR06', 5.0),
#  ('A3INN916E4VION', 'B004MPR0ZC', 5.0),
#  ('A1T1YSCDW0PD25', 'B001FWYXD2', 5.0),
#  ('A11D1KHM7DVOQK', 'B00008V6JO', 2.0),
#  ('A2UKE7GIVC7XFW', 'B004NY9UZA', 4.0),
#  ('A197T2N6RU7K56', 'B00CCKDOYU', 5.0),
#  ('A3BNMHRW2R35LK', 'B00IUJAJD6', 5.0),
#  ('A3FOSLM5G1BO63', 'B009O7Y8ZI', 4.0),
#  ('A2NB2E5DXE319Z', 'B008JJLW4M', 5.0),
#  ('A16QODENBJVUI1', 'B00DQZRKY0', 5.0),
#  ('ADOR3TR7GDF68', 'B004XC6GJ0', 5.0),
#  ('A84FLVDK2R5JF', 'B00884WH74', 4.0),
#  ('AV8MDYLHHTUOY', 'B009SYZ8OC', 5.0),
#  ('A3V7D0LH8L7BG0', 'B000NB05MO', 5.0),
#  ('A19W47CXJJP1MI', 'B003CJTR8M', 5.0),
#  ('A36K2N527TXXJN', 'B005IZ65G0', 4.0),
#  ('A213J54E63SYOP', 'B00B2AT8DW', 3.0),
#  ('A3LPL35P7FH78Y', 'B003MULNRY', 5.0),
#  ('A2BLFCOPSMBOZ9', 'B00CKAQZTS', 5.0),
#  ('A3N4VTNFPMTHEF', 'B008C1JC4O', 4.0),
#  ('A27M75LRSJ788H', 'B001UE6MIO', 5.0),
#  ('A3SQCTNYQFVBWM', 'B00H4XF2HC', 4.0),
#  ('A1QQA7Y92L4F9R', 'B002XZLURC', 5.0),
#  ('A1NGFGBX2VCQS8', 'B00CHT6CRC', 5.0),
#  ('AOEDWQLH2WKKW', 'B000MFLQR4', 4.0),
#  ('A1NNMOD9H36Q8E', 'B0000BZLBA', 4.0),
#  ('A10ZFE6YE0UHW8', 'B000067TP9', 4.0),
#  ('A1U4GOVZWL8ZTL', 'B0083KGXC8', 4.0),
#  ('A1MRPX3RM48T2I', 'B00BDS3N1G', 4.0),
#  ('AT28RL25Q2OLK', 'B00AQ2BU74', 5.0),
#  ('A3SQCTNYQFVBWM', 'B00D6XSRL2', 4.0),
#  ('A22I55P15NSAOX', 'B003B3P2CO', 5.0),
#  ('A1F1A0QQP2XVH5', 'B0088CJT4U', 4.0),
#  ('A2LW5AL0KQ9P1M', 'B00HPM1G8Q', 2.0),
#  ('AV10H5K6VPQIJ', 'B00D41CYOW', 5.0),
#  ('A6FIAB28IS79', 'B00005LB8P', 5.0),
#  ('A18U49406IPPIJ', 'B00DSX557O', 5.0),
#  ('A3EK2KTYHJCPB9', 'B00BGIQPSG', 4.0),
#  ('A3F3B6HY9RJI04', 'B0000AQIFZ', 5.0),
#  ('A3U41ZL33SS92P', 'B0015GADB4', 3.0),
#  ('ADLVFFE4VBT8', 'B000RPXE74', 4.0),
#  ('A2UTZ4O5E2W4DK', 'B002P4YXI4', 5.0),
#  ('AWSK1ZAEU1KFL', 'B00FQJEJNY', 1.0),
#  ('A3E049PVKG7NDK', 'B0046UOGXW', 4.0),
#  ('A2ROZACRW31PC2', 'B0055XKBW4', 4.0),
#  ('A3UR2N0ATGBCU8', 'B005GYDMYG', 5.0),
#  ('A25FL6VLD7S23S', 'B005NN8V3M', 5.0),
#  ('A33YZNZIRA3H97', 'B000GLHDH6', 4.0),
#  ('A19HT7YC1UW3D6', 'B007P4YAPK', 5.0),
#  ('A3775OP5VTX5ON', 'B002VR6A9K', 5.0),
#  ('A1EXGL6L0QQ0M5', 'B00D9BL07E', 5.0),
#  ('A19HT7YC1UW3D6', 'B006PWGEVQ', 5.0),
#  ('A4UGMKUSX9XHI', 'B007FGYZFI', 5.0),
#  ('A1VHCO8RQFIGQJ', 'B000VY2BC0', 4.0),
#  ('A1EXGL6L0QQ0M5', 'B002LARRDK', 4.0),
#  ('AFNG8O2DXRCUV', 'B0002U1TJY', 4.0),
#  ('A27H0T39U3FZB5', 'B002V88HFE', 5.0),
#  ('ADLVFFE4VBT8', 'B0026MF17C', 4.0),
#  ('A680RUE1FDO8B', 'B005HY4U46', 5.0),
#  ('A3W4D8XOGLWUN5', 'B002L6HECS', 2.0),
#  ('A1WF4QNIE2Z3I7', 'B0034CL2ZI', 4.0),
#  ('A1VQHH85U7PX0', 'B00009R6UU', 5.0),
#  ('A23GFTVIETX7DS', 'B0011ZXG7M', 5.0),
#  ('ACYZXQ2JKPZKT', 'B0025EWXEU', 4.0),
#  ('A2QRXQPHDMFCQV', 'B004DMNT2W', 2.0),
#  ('A3VI2VETB90ZG5', 'B003924UBG', 4.0),
#  ('A6FIAB28IS79', 'B003L77Y5I', 5.0),
#  ('A1F1A0QQP2XVH5', 'B0028RXI5C', 3.0),
#  ('A37IRE9GZ0CZ7I', 'B00E1HIVG8', 4.0),
#  ('A36K2N527TXXJN', 'B00D3F7D7M', 4.0),
#  ('A5JLAU2ARJ0BO', 'B0006MWHMG', 5.0),
#  ('A1EKSETIBS9ETQ', 'B0040IUI46', 5.0),
#  ('A1RJKTYC03L0JY', 'B001AZ3UHY', 5.0),
#  ('A3REK3OFONWB1Q', 'B000AUQICO', 5.0),
#  ('A1EVV74UQYVKRY', 'B0007LBON4', 4.0),
#  ('ADLVFFE4VBT8', 'B000EMTJ92', 5.0),
#  ('A31ICLWQ9CSHRS', 'B0093H4WT6', 5.0),
#  ('AT6CZDCP4TRGA', 'B0002553PA', 2.0),
#  ('A2WB7LZ595CR50', 'B0039JBXVY', 5.0),
#  ('A1QOK9LU90ACF7', 'B001T9N9JU', 3.0),
#  ('A28N2AWOVO2PB', 'B00972M942', 5.0),
#  ('ARBKYIVNYWK3C', 'B005DKZTMG', 5.0),
#  ('A21I62TCDL4754', 'B0046SB5L0', 4.0),
#  ('A357B3PUHSVQA', 'B0086KP1I2', 3.0),
#  ('A1B6O7SAIYG2N0', 'B003Q6CU12', 4.0),
#  ('AJX9A4Q19UTJU', 'B0051FWA7U', 3.0),
#  ('A2LW5AL0KQ9P1M', 'B00DQZOD8Q', 4.0),
#  ('AEJAGHLC675A7', 'B001287F4S', 5.0),
#  ('A1ODOGXEYECQQ8', 'B00KYMCJF8', 5.0),
#  ('A2S26YGSVXBCFL', 'B00005I9RL', 5.0),
#  ('A2V5M5EJPOD2IU', 'B009SPUY5O', 4.0),
#  ('ABQWMANK4AR63', 'B00CIRLJPI', 4.0),
#  ('A20951I210L0IB', 'B004SZFCPG', 4.0),
#  ('A2IT7S59GSASN7', 'B00ARB5FLQ', 1.0),
#  ('A3NOBH42C7UI5M', 'B0003QER7S', 1.0),
#  ('A1GQRGB8FGSLIZ', 'B0076MBOC8', 5.0),
#  ('AWPODHOB4GFWL', 'B00005B6YF', 5.0),
#  ('A2YHXGPCTENZY3', 'B000I661J0', 2.0),
#  ('A18FLOC8YQY0P8', 'B004WYA852', 5.0),
#  ('A36K2N527TXXJN', 'B0082E9K7U', 4.0),
#  ('A26EQ8U96JA92T', 'B0038W0N8G', 5.0),
#  ('A1AQ8JT2A3UWMY', 'B000X24ISU', 5.0),
#  ('A3T7V207KRDE2O', 'B004SBI2MU', 5.0),
#  ('AW68KVDV7BBRS', 'B00429N18S', 1.0),
#  ('A1X2LENOF84LCQ', 'B0035WTVZA', 4.0),
#  ('A19HKRB4LU5YR', 'B0051UY168', 4.0),
#  ('A1VUN4JU731CBH', 'B0017TFVUW', 3.0),
#  ('A23GFTVIETX7DS', 'B00FDK4GXY', 4.0),
#  ('A11I1I9QLMAM1A', 'B00GDL2PPI', 5.0),
#  ('A15QYHQH80W30L', 'B000C0QGAQ', 5.0),
#  ('A23QII83UGZP5U', 'B00J49ZH1U', 4.0),
#  ('A1XXMNLOLKNO0I', 'B000ACGQI8', 5.0),
#  ('A3HSDV9Y0TV5Z2', 'B005QOF0YQ', 5.0),
#  ('A25FL6VLD7S23S', 'B004YI9HG2', 5.0),
#  ('A23NSKTMSPPBTR', 'B001T2ABWA', 4.0),
#  ('A10PEXB6XAQ5XF', 'B004VRJ3FQ', 5.0),
#  ('A1NGFGBX2VCQS8', 'B009AR2MFK', 4.0),
#  ('A1R377IPZOKLMM', 'B000ANOY7M', 5.0),
#  ('A203OCQQ12MAVT', 'B000AZJ268', 4.0),
#  ('A3PDWA32BAMB2Y', 'B001O4GL36', 4.0),
#  ('A2XRMQA6PJ5ZJ8', 'B006EWUP4Y', 5.0),
#  ('A18HE80910BTZI', 'B0064XAIZY', 4.0),
#  ('AFR9GYKAHM37U', 'B0000BVYTV', 4.0),
#  ('A231WM2Z2JL0U3', 'B00009J5W0', 5.0),
#  ('A2NOW4U7W3F7RI', 'B00FDLGMJE', 5.0),
#  ('A3NKRH3TJ4DPVI', 'B001F7AJKI', 5.0),
#  ('ARXU3FESTWMJJ', 'B00005Y1Z6', 4.0),
#  ('A2KOV8XWZOZ0FQ', 'B006K550J0', 4.0),
#  ('A376OJHLE6SU9Q', 'B003X26PMO', 5.0),
#  ('A1B6O7SAIYG2N0', 'B002LTWDSK', 5.0),
#  ('A2SKEQT0WTB954', 'B0038SNTY0', 5.0),
#  ('A2IFGGXG3YV3Y6', 'B0036WT3ZM', 5.0),
#  ('A31ICLWQ9CSHRS', 'B000067O7U', 2.0),
#  ('A23GFTVIETX7DS', 'B001MSF1FI', 5.0),
#  ('A1QNYLBG73QRNF', 'B005O9YMM4', 5.0),
#  ('A2WB7LZ595CR50', 'B000EMCZ52', 1.0),
#  ('A2L90SGUP36KGA', 'B006W3ZXG0', 4.0),
#  ('A2NOW4U7W3F7RI', 'B000ANCPNM', 5.0),
#  ('ATZJNEXX7LWD3', 'B0031RG29M', 3.0),
#  ('A25HBO5V8S8SEA', 'B0000DJEIP', 5.0),
#  ('A35HNL2VEDK9Z1', 'B001GIPR62', 4.0),
#  ('A3A4ZAIBQWKOZS', 'B007BXD66E', 5.0),
#  ('A3F3B1JPACN215', 'B005ZAO9PC', 5.0),
#  ('A28BX3MM90A6FI', 'B003QH2MY6', 3.0),
#  ('A1CMD08Z49PGKQ', 'B00AFH3IN4', 5.0),
#  ('ATS2855497V0I', 'B00435PI3W', 4.0),
#  ('A3J8A5L5AF5TX9', 'B000KW5OFY', 2.0),
#  ('A12DQZKRKTNF5E', 'B008BR5XBK', 4.0),
#  ('A29KJ32G75L7G9', 'B00CR00IZI', 5.0),
#  ('A34BZM6S9L7QI4', 'B00I0G8GNY', 5.0),
#  ('A3F3B1JPACN215', 'B003VVH8Y6', 5.0),
#  ('A6FIAB28IS79', 'B0000TQ154', 3.0),
#  ('A250AXLRBVYKB4', 'B001ISK6FW', 4.0),
#  ('A25QJBK33C4O0R', 'B004CLY5DG', 4.0),
#  ('A680RUE1FDO8B', 'B001THDD8O', 3.0),
#  ('A3LGT6UZL99IW1', 'B001N0KEWU', 4.0),
#  ('A20DZX38KRBIT8', 'B001ATK8A2', 1.0),
#  ('A25C2M3QF9G7OQ', 'B00KFBX9XY', 5.0),
#  ('A1ILWPH1GHUXE2', 'B008RW6RGE', 4.0),
#  ('A3NG7X4APIV649', 'B0027AGK3M', 5.0),
#  ('A328S9RN3U5M68', 'B00EHJ6DV0', 5.0),
#  ('ABQWMANK4AR63', 'B0046TJG1U', 5.0),
#  ('A3CW0ZLUO5X2B1', 'B008RMG96W', 4.0),
#  ('A3CW0ZLUO5X2B1', 'B004MMEHH4', 5.0),
#  ('A3CG93783LP0FO', 'B0031RGEVI', 4.0),
#  ('A2HMF8ZR67BNZS', 'B003VVH8Y6', 5.0),
#  ('A2UOHALGF2X77Q', 'B000LRMS66', 4.0),
#  ('A2PSD2R9A1CXG7', 'B002COJEOU', 2.0),
#  ('A226VGZWOEBPGL', 'B0035JCI6M', 3.0),
#  ('A3S0EHEIR52HP1', 'B0041T93JK', 5.0),
#  ('A376OJHLE6SU9Q', 'B008X9ZBVI', 5.0),
#  ('A30X750M8V1XXW', 'B002LFOAOO', 5.0),
#  ('A1Z16630QMH8Q6', 'B00CO1I29O', 5.0),
#  ('A1U5IJHJK84S54', 'B000M52EBG', 1.0),
#  ('A1PL7QILVQV3IF', 'B001SEQN3U', 3.0),
#  ('A3F3B6HY9RJI04', 'B0001M2FZK', 4.0),
#  ('A1BBYSMT9YCODI', 'B00BE68UZ6', 5.0),
#  ('A2WC9NFLG57W4H', 'B002PU9SQU', 5.0),
#  ('A1O229NVVDJUX2', 'B00395WIXA', 4.0),
#  ('A2W9GX82SLKROQ', 'B002EF2200', 4.0),
#  ('A1ODOGXEYECQQ8', 'B0076POAPS', 2.0),
#  ('A17BUUBOU0598B', 'B000VZCEUI', 3.0),
#  ('AWH2AY17ZU7W2', 'B00BSEV682', 4.0),
#  ('A3OXHLG6DIBRW8', 'B002GTAUT4', 5.0),
#  ('A3INN916E4VION', 'B003UE52ME', 4.0),
#  ('A23GFTVIETX7DS', 'B002XOLT7Y', 5.0),
#  ('A22MANL4US4RMY', 'B0052SCU8U', 5.0),
#  ('ASJSX783R5HTZ', 'B0000E2Y7Q', 5.0),
#  ('A186697K4XKXQL', 'B003YTROIU', 3.0),
#  ('A35W3JQYP0M655', 'B003UE52ME', 4.0),
#  ('A328S9RN3U5M68', 'B00D1V2882', 5.0),
#  ('ABXANRX4GPYRZ', 'B000U9WVW6', 5.0),
#  ('A2YHXGPCTENZY3', 'B0013PVRQM', 4.0),
#  ('ARIDN94LOCQFD', 'B003U8K65S', 5.0),
#  ('A1SB9BNNGKNX2Z', 'B009X2OS5Y', 5.0),
#  ('AVBLGXSWRN666', 'B001IWJSCK', 4.0),
#  ('AEAFHD09X8044', 'B001JQ4PY6', 4.0),
#  ('A3TRY87JJCA5Y8', 'B005CPT35Q', 5.0),
#  ('A32QOZWIKQDNZX', 'B00005LKXS', 5.0),
#  ('A6FIAB28IS79', 'B0011ZK6PC', 5.0),
#  ('A6FIAB28IS79', 'B00005ML56', 2.0),
#  ('A31BD4RXCON7QO', 'B000R30GGI', 5.0),
#  ('A3OA4DV4L81N1D', 'B00264GYMG', 3.0),
#  ('A54S9CIUV5VNB', 'B0009HGVZW', 5.0),
#  ('A3AYSYSLHU26U9', 'B00FRBCSUW', 4.0),
#  ('AYMD77ITD15PT', 'B004IBK3PE', 5.0),
#  ('A240FRPD4MEXND', 'B0038KV2MO', 4.0),
#  ('A23GFTVIETX7DS', 'B0002XN3WW', 4.0),
#  ('A259MPG6SOL02P', 'B00004TDMX', 3.0),
#  ('A6FIAB28IS79', 'B000F7JCRA', 5.0),
#  ('A1A5KUIIIHFF4U', 'B00007IFED', 5.0),
#  ('AGVWTYW0ULXHT', 'B0053R0WWG', 4.0),
#  ('A2503LT8PZIHAD', 'B00IF0JAIU', 4.0),
#  ('A3EZFFPVS34AMO', 'B00ATZ9I90', 5.0),
#  ('A26EQ8U96JA92T', 'B0042FZ51I', 5.0),
#  ('AFNG8O2DXRCUV', 'B002OEBMZM', 4.0),
#  ('AOEAD7DPLZE53', 'B003U9VONU', 1.0),
#  ('A3A4ZAIBQWKOZS', 'B004C9P9TM', 5.0),
#  ('AMVXR3NPL0GWX', 'B001CCAISE', 5.0),
#  ('A3QNQQKJTL76H0', 'B001CZ5BOW', 4.0),
#  ('A5JLAU2ARJ0BO', 'B0002PSINY', 4.0),
#  ('A1WXG10FJ353K0', 'B0010WG2H2', 1.0),
#  ('A2AEZQ3DGBBLPR', 'B0000VYJRY', 3.0),
#  ('A3284KYDZ00BZA', 'B000A5TAT2', 5.0),
#  ('A23QII83UGZP5U', 'B008F4NL04', 3.0),
#  ('A10PEXB6XAQ5XF', 'B005S1CYO6', 3.0),
#  ('A2HRHF83I3NDGT', 'B003690Q42', 5.0),
#  ('A3NEAETOSXDBOM', 'B004GF8TIK', 5.0),
#  ('A3P1508PZ0UADD', 'B000BMMORO', 5.0),
#  ('A3977M5S0GIG5H', 'B00005T39Y', 5.0),
#  ('AW6J9IILGOZY3', 'B004I5BUSO', 4.0),
#  ('A3NOBH42C7UI5M', 'B00009W3UH', 5.0),
#  ('A149RNR5RH19YY', 'B00113PUJQ', 4.0),
#  ('A3MFORLOKIOEQY', 'B008Y1KK6Q', 5.0),
#  ('A11T807LX2EF00', 'B00829TIEK', 5.0),
#  ('AROQO2VDODT7', 'B0007DDK7A', 4.0),
#  ('A22CW0ZHY3NJH8', 'B005QCDY50', 4.0),
#  ('A26BDXG9KVH7SU', 'B0044XU43C', 5.0),
#  ('A204K1OFE8OB9Y', 'B0007U0GZM', 4.0),
#  ('A32O5FZH994CNY', 'B006Y443TU', 5.0),
#  ('A26KXNN6H1IL0I', 'B00BOHNYTW', 5.0),
#  ('A32T2H8150OJLU', 'B001T6O0ZK', 5.0),
#  ('A1SHHQSPOWR00F', 'B004WYA852', 5.0),
#  ('A26BDXG9KVH7SU', 'B009NHWVIA', 3.0),
#  ('A2R6RA8FRBS608', 'B00017G89E', 4.0),
#  ('ARBKYIVNYWK3C', 'B005MZU0JY', 5.0),
#  ('A3GVXKCTFN3YDN', 'B006O143QQ', 5.0),
#  ('A2V9DTXTQ5YIMK', 'B003FSTAFK', 3.0),
#  ('A3GVXKCTFN3YDN', 'B004CLYEE6', 5.0),
#  ('A3R4794K2RVU1S', 'B0026ZPFCK', 5.0),
#  ('A6VXZ1EEPRTLV', 'B00CIZ2238', 4.0),
#  ('A22CW0ZHY3NJH8', 'B002R04DMW', 4.0),
#  ('A3RGJ1FXOB1ZLL', 'B000BUDHOA', 5.0),
#  ('AGOH8N902URMW', 'B00BAJ1QDA', 5.0),
#  ('AC6Z7DP1Z5GHD', 'B004G8CBFY', 5.0),
#  ('A7QMQBGJ2TCQG', 'B002T7KIXQ', 5.0),
#  ('A2W9GX82SLKROQ', 'B00D8X0HFE', 4.0),
#  ('AGXV8E7XK9J6H', 'B000F2YHRA', 4.0),
#  ('A3BKNXX8QFIXIV', 'B005N3TPJQ', 5.0),
#  ('A2J7FHZFKOKGZ6', 'B000F9LMRQ', 4.0),
#  ('AGJRUK27RBVYS', 'B0030MIU16', 5.0),
#  ('A3284KYDZ00BZA', 'B004GK0GKO', 4.0),
#  ('A3HR0ZZOFKQ97N', 'B00F0DD0I6', 5.0),
#  ('A1CMD08Z49PGKQ', 'B009DI38CC', 5.0),
#  ('A1ZTR0FR5AW9B4', 'B00448MV88', 4.0),
#  ('A25C2M3QF9G7OQ', 'B002RM08RE', 5.0),
#  ('A3OXHLG6DIBRW8', 'B001T9NUJE', 4.0),
#  ('A24HWYHR28JJ7A', 'B00AXUSVRG', 4.0),
#  ('AG35JCCQWDRCS', 'B0001G0FGW', 5.0),
#  ('A3CW0ZLUO5X2B1', 'B004CCS266', 5.0),
#  ('A2RW587355CMVA', 'B005BZNE2U', 5.0),
#  ('AEL6CQNQXONBX', 'B00KWPRSJY', 5.0),
#  ('A1LD5SE8IZ1H70', 'B007EM7NES', 5.0),
#  ('AT28RL25Q2OLK', 'B004XC6GJ0', 5.0),
#  ('A2294LS59GC5K7', 'B0089V4WOC', 4.0),
#  ('A1E1LEVQ9VQNK', 'B00CHH0JF0', 5.0),
#  ('A1T1YSCDW0PD25', 'B003TSDG06', 5.0),
#  ('A2LTYEYGKBYXRR', 'B00A0ZMCFG', 5.0),
#  ('A370XYLIZCSK1Y', 'B00347L6I6', 5.0),
#  ('A2S26YGSVXBCFL', 'B002MCZ2L6', 5.0),
#  ('A1L64KDYO5BOJA', 'B000MY07GQ', 3.0),
#  ('A26BDXG9KVH7SU', 'B0038BW3W6', 2.0),
#  ('A1GQRGB8FGSLIZ', 'B00C7EPU0M', 4.0),
#  ('A2VODABWSVHV8E', 'B000VXT1ZG', 5.0),
#  ('A3CW0ZLUO5X2B1', 'B00DKBU5W4', 5.0),
#  ('A2L42QEWR77PKZ', 'B0083X8X0U', 4.0),
#  ('A10PEXB6XAQ5XF', 'B00406YHLI', 4.0),
#  ('A1U4GOVZWL8ZTL', 'B0029X8K1M', 5.0),
#  ('AXU3VKZE848IY', 'B003JOETX8', 5.0),
#  ('A10O7THJ2O20AG', 'B002YE213O', 5.0),
#  ('A35W3JQYP0M655', 'B00E3FHXYO', 5.0),
#  ('A3PD8JD9L4WEII', 'B001GXFVPE', 4.0),
#  ('A11D1KHM7DVOQK', 'B00004T8R2', 2.0),
#  ('A1EXGL6L0QQ0M5', 'B000HJ5N2Y', 5.0),
#  ('A1OMXVXXP07F05', 'B000067S60', 4.0),
#  ('AHR86ZEYETLJI', 'B00023JK8I', 5.0),
#  ('A3TBMAWIIHKHFN', 'B003LD4T0K', 4.0),
#  ('A3F3B6HY9RJI04', 'B00DQZSIW8', 5.0),
#  ('A1QNYLBG73QRNF', 'B0015AE4C4', 5.0),
#  ('A1OMXVXXP07F05', 'B000WG6XW6', 4.0),
#  ('A27ADCSD15F3GL', 'B00834SJH6', 4.0),
#  ('A1H98YV5K5BUX0', 'B001FPOD7A', 4.0),
#  ('A2BMZRO0H7TFCS', 'B00829THEG', 4.0),
#  ('AC6Z7DP1Z5GHD', 'B000F7QRTG', 5.0),
#  ('A1MFAPVBW9BEGD', 'B004HVW0ZQ', 3.0),
#  ('A250AXLRBVYKB4', 'B00116SLYY', 5.0),
#  ('AROQO2VDODT7', 'B00009R6WU', 5.0),
#  ('AZMY6E8B52L2T', 'B00CBD2X5E', 5.0),
#  ('A1V4VVBQBFXRHC', 'B0063705PE', 4.0),
#  ('A3EXWV8FNSSFL6', 'B0000BZL1P', 5.0),
#  ('A2JWF9IG8PJAOA', 'B00CQKCXXE', 5.0),
#  ('A30X750M8V1XXW', 'B00006B7DA', 5.0),
#  ('A3T4OHEAHOJ700', 'B0007M3PK8', 1.0),
#  ('A2LXX47A0KMJVX', 'B000I991LM', 5.0),
#  ('A3F7USIDJBR8WU', 'B0002J2TLC', 5.0),
#  ('A3NHUQ33CFH3VM', 'B00JDAIMQ2', 5.0),
#  ('AVBLGXSWRN666', 'B002QEBMAK', 4.0),
#  ('A3QJU4FEN8PQSZ', 'B000CS7U1C', 4.0),
#  ('A23QII83UGZP5U', 'B006ZOI9OY', 3.0),
#  ('A19XMHRB3G4DIR', 'B000271OX8', 5.0),
#  ('A8WEXFRWX1ZHH', 'B0001FTVEK', 1.0),
#  ('A1C5WS021EL3WO', 'B004TO2IAI', 5.0),
#  ('A2LTYEYGKBYXRR', 'B00GJFGDUQ', 5.0),
#  ('A11D1KHM7DVOQK', 'B00005QT5J', 2.0),
#  ('A2BMZRO0H7TFCS', 'B0035JJJQY', 4.0),
#  ('A370XYLIZCSK1Y', 'B005J4XMUM', 5.0),
#  ('AI0BCEWRE04G0', 'B001E1Y5O6', 3.0),
#  ('A2BLFCOPSMBOZ9', 'B000OFC1YY', 5.0),
#  ('A1U5NWJOYH2QQH', 'B0001WXTF0', 5.0),
#  ('A197T2N6RU7K56', 'B004QGXOOI', 5.0),
#  ('A3V5F050GVZ56Q', 'B0042SGDVG', 5.0),
#  ('AKT8TGIT6VVZ5', 'B00CI3BIWQ', 5.0),
#  ('A2OWR5G2OAQF7C', 'B002IC0YL8', 4.0),
#  ('A3PGVJF37JSHFO', 'B00011CS1C', 5.0),
#  ('A2HPJKM7L4EOQB', 'B0000226L0', 3.0),
#  ('A1E55W6ES0FY17', 'B00013MSVK', 3.0),
#  ('A35HUT8MQMT21L', 'B001IBHUU8', 2.0),
#  ('A2QDOJFFLFGF18', 'B009YQ8BTI', 5.0),
#  ('A2NP9CGUSFP22E', 'B008CBQSKU', 3.0),
#  ('ARBKYIVNYWK3C', 'B00006HQR8', 5.0),
#  ('AK3GKIV8DEY8B', 'B00D2CWLZK', 5.0),
#  ('A2LLSFQO8O8XNW', 'B001LF40LI', 5.0),
#  ('AKT8TGIT6VVZ5', 'B0007876DE', 3.0),
#  ('A2AF0NOCM71J0B', 'B00BLLX9CI', 5.0),
#  ('A10PEXB6XAQ5XF', 'B000S5Q9CA', 3.0),
#  ('A1R377IPZOKLMM', 'B00BVUQZZ2', 4.0),
#  ('A1435P5AMCPB3X', 'B000JFJRBE', 5.0),
#  ('A3A15L96IYUO6V', 'B002O0KH7K', 4.0),
#  ('A18HE80910BTZI', 'B002KKFP9Y', 3.0),
#  ('A3L6L5O89JTX2T', 'B004J3V7RO', 5.0),
#  ('A3OXHLG6DIBRW8', 'B000BSOBG0', 4.0),
#  ('A3EZEP0FX5BC1P', 'B003FSTAFK', 3.0),
#  ('AOEDWQLH2WKKW', 'B004P7GAPI', 4.0),
#  ('A35HNL2VEDK9Z1', 'B000TG4BA0', 1.0),
#  ('A1IBKN1GXYJ3K4', 'B001I6DMS2', 4.0),
#  ('A3NOBH42C7UI5M', 'B0002PS51Y', 4.0),
#  ('A2SATO5BNKWY3Y', 'B003Z4G3I6', 5.0),
#  ('A3BACUOZV1M0WM', 'B004SP0APS', 4.0),
#  ('A21I62TCDL4754', 'B002NO7PWC', 5.0),
#  ('A2NP9CGUSFP22E', 'B000UBKZRC', 3.0),
#  ('A2AF0NOCM71J0B', 'B005HNHRA6', 5.0),
#  ('A2LLSFQO8O8XNW', 'B00CPLGGXM', 5.0),
#  ('A20DZX38KRBIT8', 'B00CS6LZYO', 1.0),
#  ('A13WOT3RSXKRD5', 'B00BEHQKPC', 4.0),
#  ('A3V5F050GVZ56Q', 'B009DZIEBK', 5.0),
#  ('ABXANRX4GPYRZ', 'B000I6P1I2', 1.0),
#  ('A212MDP6K4VJS5', 'B0038KTAGO', 5.0),
#  ('A3NHUQ33CFH3VM', 'B00F3SIQKK', 4.0),
#  ('A34VRVI4CSI5RQ', 'B001PKTR76', 5.0),
#  ('A6VPK7X53QNAQ', 'B005TDWY52', 3.0),
#  ('A16RI68PS6T5CA', 'B00127VF68', 4.0),
#  ('A38NHXL5257E3B', 'B001AYCNIW', 5.0),
#  ('A1XXMNLOLKNO0I', 'B00EPPSN50', 5.0),
#  ('A1H4IVXNXWWBLV', 'B00009R970', 5.0),
#  ('A4WEZJOIZIV4U', 'B000N8DJB6', 5.0),
#  ('A1MFVAHTT2BHM0', 'B0090EC5MS', 3.0),
#  ('AN81JUYW2SL24', 'B00275XTSQ', 4.0),
#  ('ACHTDPEQYSEQL', 'B00858I53S', 4.0),
#  ('AOEDWQLH2WKKW', 'B005NGOPSY', 3.0),
#  ('AYB4ELCS5AM8P', 'B008ULPE70', 5.0),
#  ('A1V3TRGWOMA8LC', 'B0038KTAXW', 5.0),
#  ('A23NSKTMSPPBTR', 'B003N2POXK', 5.0),
#  ('A10PEXB6XAQ5XF', 'B0079UAT0A', 4.0),
#  ('A2XRMQA6PJ5ZJ8', 'B004352QXM', 4.0),
#  ('A2BLFCOPSMBOZ9', 'B0067WUSGQ', 5.0),
#  ('A1O229NVVDJUX2', 'B00284ALF0', 5.0),
#  ('A186697K4XKXQL', 'B004TKTOWC', 3.0),
#  ('AGGAQLXPVGM5D', 'B001S2RCWI', 5.0),
#  ('A100WO06OQR8BQ', 'B00004TDRH', 5.0),
#  ('A1A5KUIIIHFF4U', 'B00A1PCKM0', 3.0),
#  ('A1U5NWJOYH2QQH', 'B004HO6HYS', 5.0),
#  ('A13BX9O5UDBILC', 'B0074F5DKG', 5.0),
#  ('A3S3R88HA0HZG3', 'B006WVR9GY', 5.0),
#  ('ADOR3TR7GDF68', 'B006TK44D4', 5.0),
#  ('A6VXZ1EEPRTLV', 'B00K5IVF1K', 5.0),
#  ('A6XDZ1MJ0B1A2', 'B004KABG18', 5.0),
#  ('A3N4VTNFPMTHEF', 'B000FTLSR0', 5.0),
#  ('A18OTCHQ6MXD6X', 'B0006VT1TY', 5.0),
#  ('A27ADCSD15F3GL', 'B007ILFFS6', 5.0),
#  ('A1O229NVVDJUX2', 'B004C13VWC', 4.0),
#  ('A27H0T39U3FZB5', 'B0035MDZKM', 4.0),
#  ('ADOR3TR7GDF68', 'B0046V20ZW', 5.0),
#  ('A39137LW12KK7B', 'B0072N4TNW', 5.0),
#  ('A1TQZUSOU22E9M', 'B005TDWVTQ', 5.0),
#  ('A17BUUBOU0598B', 'B008VD4BU8', 3.0),
#  ('A2HPJKM7L4EOQB', 'B0007U00W6', 5.0),
#  ('A1UQBFCERIP7VJ', 'B00HFFDDLG', 5.0),
#  ('A18FLOC8YQY0P8', 'B000YQNLQK', 3.0),
#  ('A3IOQ7NVVLAUEE', 'B0043SIX4A', 5.0),
#  ('A3QNQQKJTL76H0', 'B002KG0JMG', 2.0),
#  ('AWSK1ZAEU1KFL', 'B007JMW0DC', 4.0),
#  ('AT28RL25Q2OLK', 'B0019CSVMW', 5.0),
#  ('A2V7EO331SFUF6', 'B00083Y4HO', 3.0),
#  ('A2UWPPU5GZLMQZ', 'B0046EDB84', 5.0),
#  ('A1XE3M22N91451', 'B005CT56F8', 5.0),
#  ('A2VODABWSVHV8E', 'B000JE5CKA', 5.0),
#  ('A2SH6A32BE6NEV', 'B00EOI2SR2', 5.0),
#  ('A29KJ32G75L7G9', 'B0074BW614', 5.0),
#  ('ADKZOXAOV8EXD', 'B000Z80ICM', 5.0),
#  ('A213J54E63SYOP', 'B00E5Z3R6A', 4.0),
#  ('A4D5B7Q8A7PA6', 'B009NHWVIA', 5.0),
#  ('A1IU7S4HCK1XK0', 'B00BW6KCTU', 5.0),
#  ('A3OXHLG6DIBRW8', 'B00004Z5KI', 5.0),
#  ('A36A1ZYZH8568P', 'B0079R8KO0', 5.0),
#  ('A3HSDV9Y0TV5Z2', 'B0053LM86A', 5.0),
#  ('A3NG7X4APIV649', 'B001V399GG', 2.0),
#  ('A2NB2E5DXE319Z', 'B007R5YDYA', 5.0),
#  ('A10X9ME6R66JDX', 'B0052SCU8U', 5.0),
#  ('A2AY4YUOX2N1BQ', 'B004FM4UFK', 5.0),
#  ('A5JLAU2ARJ0BO', 'B00004TVSO', 2.0),
#  ('A2T689YVOAYGGD', 'B0040JHVC2', 5.0),
#  ('A3775OP5VTX5ON', 'B005420JFA', 4.0),
#  ('A1MFVAHTT2BHM0', 'B005HPSFWI', 3.0),
#  ('A2ZY49IDE6TY5I', 'B0071CE2ZE', 3.0),
#  ('AYB4ELCS5AM8P', 'B00JKO8QRG', 5.0),
#  ('AXU3VKZE848IY', 'B000IS1ZYY', 3.0),
#  ('A1PVJICI412IN4', 'B004GN6376', 4.0),
#  ('A1F9Z42CFF9IAY', 'B0043GCBU4', 2.0),
#  ('ASJSX783R5HTZ', 'B002P3KY7E', 5.0),
#  ('A28UMA3GW9L124', 'B00EZSUVHU', 4.0),
#  ('A1U4GOVZWL8ZTL', 'B002V88HFE', 5.0),
#  ('A20DZX38KRBIT8', 'B0012GQZZU', 1.0),
#  ('A3FEGTOLCWXSV4', 'B001VEJEG0', 3.0),
#  ('A6FIAB28IS79', 'B004FEEZLW', 5.0),
#  ('A680RUE1FDO8B', 'B0007UY662', 5.0),
#  ('A2NSXY5L42ZUGO', 'B00295RAMK', 5.0),
#  ('A2V7EO331SFUF6', 'B00005U21H', 5.0),
#  ('A6FIAB28IS79', 'B000V0DY02', 4.0),
#  ('A1RPTVW5VEOSI', 'B00006RH5I', 5.0),
#  ('A2BMZRO0H7TFCS', 'B001TH7GVE', 5.0),
#  ('A2XRMQA6PJ5ZJ8', 'B003K1EYM6', 4.0),
#  ('A39137LW12KK7B', 'B0093H4WT6', 5.0),
#  ('A3R4794K2RVU1S', 'B004T9RR6I', 5.0),
#  ('A1F1A0QQP2XVH5', 'B008AL9VXI', 5.0),
#  ('A1KXJCXS6HFRQZ', 'B006WHPQCM', 2.0),
#  ('A5KMMY627T3W', 'B005INAIOW', 5.0),
#  ('ARBKYIVNYWK3C', 'B002OGMNT4', 4.0),
#  ('A100UD67AHFODS', 'B007E8IJM2', 1.0),
#  ('A18FLOC8YQY0P8', 'B003LJ94K4', 3.0),
#  ('A3AYSYSLHU26U9', 'B004GUT1QO', 5.0),
#  ('A2V7EO331SFUF6', 'B0060NQG6S', 3.0),
#  ('AYNAH993VDECT', 'B008OEHV6U', 4.0),
#  ('ABQWMANK4AR63', 'B001QKI2DA', 3.0),
#  ('A2XRMQA6PJ5ZJ8', 'B003CFB1AS', 4.0),
#  ('A1UEL5C1N6E5SE', 'B000BF0XEW', 4.0),
#  ('A19UTUEBWKIZFT', 'B004E4YGIA', 5.0),
#  ('A3LWC833HQIG7J', 'B0057ODG6Y', 5.0),
#  ('A3A15L96IYUO6V', 'B001DJ64C0', 4.0),
#  ('A19W47CXJJP1MI', 'B00BEHRQB4', 5.0),
#  ('A3TRY87JJCA5Y8', 'B003TQN2VG', 5.0),
#  ('A3094EPI56GKZ6', 'B005MI8NJA', 5.0),
#  ('AEAFHD09X8044', 'B003YFG12E', 5.0),
#  ('A316XO4RWX21YN', 'B002SZEOLG', 4.0),
#  ('A2BX8DDQGCCG2J', 'B008D9HZ62', 5.0),
#  ('A3TRY87JJCA5Y8', 'B00009R957', 2.0),
#  ('A3077MQTAKOVFZ', 'B000136P8W', 5.0),
#  ('A3OXHLG6DIBRW8', 'B003U69BX8', 4.0),
#  ('A7EU2BWLLCJY2', 'B00HVMIL1U', 5.0),
#  ('A2DG63DN704LOI', 'B003FMVCRU', 5.0),
#  ('A2AX2UGB167J31', 'B000BSN4UY', 5.0),
#  ('A2NJQF2UI60VGT', 'B001E0RZ3U', 5.0),
#  ('ASJSX783R5HTZ', 'B008U2HTIQ', 3.0),
#  ('A1KXJCXS6HFRQZ', 'B008M11XO6', 3.0),
#  ('A3LPL35P7FH78Y', 'B0074J7ITG', 5.0),
#  ('A20VG5W98SX99L', 'B00834SJNA', 4.0),
#  ('A14JBDSWKPKTZA', 'B0017U8FVI', 4.0),
#  ('A17HMM1M7T9PJ1', 'B000NP3DJW', 4.0),
#  ('A38NHXL5257E3B', 'B00E6N9GS4', 5.0),
#  ('AZ515FFZ7I2P7', 'B0013IWYHU', 4.0),
#  ('A2SH6A32BE6NEV', 'B0014SWPO6', 5.0),
#  ('A1JUBRIZMO0RJV', 'B0007Y7976', 5.0),
#  ('A213J54E63SYOP', 'B008OV6PWY', 4.0),
#  ('ALQ4USPEQ9L5N', 'B005W17MHG', 5.0),
#  ('A1MJMYLRTZ76ZX', 'B000MQACHS', 4.0),
#  ('AQIJ3ZEEVCIKU', 'B0025VKUQ6', 3.0),
#  ('A370XYLIZCSK1Y', 'B004W2JL2A', 5.0),
#  ('A2YHXGPCTENZY3', 'B000RQHAUA', 1.0),
#  ('A3Q4TYJVAM4IRM', 'B002SRZCK6', 5.0),
#  ...]

# %%
test_pred = svd_model.test(testset)

# %%
# compute RMSE
accuracy.rmse(test_pred)
# Out:
# RMSE: 2.0845
# 2.0844725075510953

# %%
uid = "A3Q4TYJVAM4IRM"  # raw user id (as in the ratings file). They are **strings**!
iid = "B000RQHAUA"  # raw item id (as in the ratings file). They are **strings**!

# %%
# get a prediction for specific users and items.
pred = svd_model.predict(uid, iid, r_ui=0.0, verbose=True)
# Out:
# user: A3Q4TYJVAM4IRM item: B000RQHAUA r_ui = 0.00   est = 1.62   {'was_impossible': False}

# %%
pred = pd.DataFrame(test_pred)
pred[pred['uid'] == "A3Q4TYJVAM4IRM"][['iid', 'r_ui']].sort_values(by = 'r_ui',ascending = False).head(10)
# Out:
#               iid  r_ui
# 138    B003CFATT2   5.0
# 11287  B000AZ57M6   5.0
# 7438   B0007RBWSU   5.0
# 8009   B001DJ64C0   5.0
# 8528   B0002SQ0A4   5.0
# 199    B000W67G72   5.0
# 17736  B002I3OZB2   5.0
# 9906   B0000ANEX9   5.0
# 16584  B00JC31SGG   5.0
# 6286   B00834SJSK   5.0
